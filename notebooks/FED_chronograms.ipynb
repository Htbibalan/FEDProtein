# %%
import pandas as pd
from datetime import datetime
import numpy as np
import trompy as tp

# %run ..//source//FED_functions.py
# Out:
# File is excel file. Making csv metafile first
# File is excel file. Making csv metafile first
# File is excel file. Making csv metafile first

# %%
mice.keys()
# Out:
# dict_keys(['FEDXA01', 'FEDXA02', 'FEDXA03', 'FEDXA04', 'FEDXA05', 'FEDXA06', 'FEDXA07', 'FEDXA08', 'FEDXA09', 'FEDXA10', 'FEDXA11', 'FEDXA12', 'FEDXB01', 'FEDXB02', 'FEDXB03', 'FEDXB04', 'FEDXB05', 'FEDXB06', 'FEDXB07', 'FEDXB08', 'FEDXB10', 'FEDXB11', 'FEDXB12'])

# %%
data = mice["FEDXA01"]["pr_timestamps"]

# %%
def remove_days(timestamp):
    while timestamp > 24:
        timestamp = timestamp - 24

    return timestamp

def get_pellets_per_hour(timestamps):

    
data_cleaned = [remove_days(timestamp) for timestamp in data]
data_hist = np.histogram(data_cleaned, bins=24)

# %%
import matplotlib.pyplot as plt

# %%
hours = [np.radians(x*(360/24)) for x in range(25)]
pellets = list(data_hist[0]) + [data_hist[0][0]]
print(len(pellets))
plt.polar(hours, pellets)
# Out:
# 25

# %%
data_hist[0]
# Out:
# array([ 44,  59,  51,  35,  35,  39,  25,  28,  33,  22,  26,  39,  54,
#         73, 101, 118, 130,  92,  92,  42,  67,  30,  73,  76], dtype=int64)

# %%
plt.plot(range(24), data_hist[0])

# %%
data_x = [0, 1, 2]
data_y = [100, 100, 100]

plt.polar(data_x, data_y)
